# %% [markdown]
# # Heart Disease Challenge

# %% [markdown]
# **[[heart disease dataset]](https://archive.ics.uci.edu/ml/datasets/Heart+Disease)**
#
# In this challange we are going to apply Machine Learning analysus on the Hart Disease dataset.
#
# The dataset is provided by four different sources:
#
# - Hungarian Institute of Cardiology
# - University Hospital, Zurich, Switzerland
# - University Hospital, Basel, Switzerland
# - V.A. Medical Center, Long Beach and Cleveland Clinic Foundation
#
# ##### Data Set Information
#
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular, the Cleveland database is the only one that has been used by ML researchers to
# this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0).
#
# ---
#
# ##### Attribute Information
# Only 14 attributes used:
# 1. age: age in years
# 2. sex: sex (1=male; 0=female)
# 3. cp: chest pain type
#
#     -- Value 1: typical angina
#     -- Value 2: atypical angina
#     -- Value 3: non-anginal pain
#     -- Value 4: asymptomatic
#
#
# 4. trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# 7. restecg: resting electrocardiographic results
#
#     -- Value 0: normal
#     -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#     -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
#
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina (1 = yes; 0 = no)
# 10. oldpeak = ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
#
#     -- Value 1: upsloping
#     -- Value 2: flat
#     -- Value 3: downsloping
#
#
# 12. ca: number of major vessels (0-3) coloured by flourosopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# 14. num: diagnosis of heart disease (angiographic disease status)
#
#     -- Value 0: < 50% diameter narrowing
#     -- Value 1: > 50% diameter narrowing
#
#
# (in any major vessel: attributes 59 through 68 are vessels)
#
# ---

# %% [markdown]
# **Goal**
#
# This dataset gives a number of variables along with a target condition of having or not having heart disease. The goal of this alayses is to find the major factors that have an impact over the health of people, because understanding the risks will help to prevent a heart attack.
#
# According to this [source](https://www.heart.org/en/health-topics/heart-attack/understand-your-risks-to-prevent-a-heart-attack), the more risk factors you have, and the greater the degree of each risk factor, the higher your chance of developing coronary heart disease – a common term for the buildup of plaque in the heart’s arteries that could lead to heart attack.
#
# The major factors that can't be changed are: increasing age, male gender and heredity.
# Note that thalassemia, one of the variables in this dataset, is heredity.
#
# Major factors that can be modified are: Smoking, high cholesterol, high blood pressure, physical inactivity, and being overweight and having diabetes. Other factors include stress, alcohol and poor diet/nutrition.

# %% [markdown]
# ### Load Basic Libraries

# %%
# Import packages
import numpy as np
import pandas as pd

import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Change default style
sns.set_style('whitegrid')

# %% [markdown]
# ### Data

# %%
# Reading the csv file and basic information
data = pd.read_csv('heart.csv')

# %%
# The head method operates on a dataframe by displaying a number of rows. The first 5 rows are displayed if no arguments are passed.
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.describe([.05, .95])
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 5%      39.100000    0.000000    0.000000  108.000000  175.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 95%     68.000000    1.000000    3.000000  160.000000  326.900000    1.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 5%       0.000000  108.100000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 95%      1.000000  181.900000    1.000000    3.400000    2.000000    3.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 5%       1.000000    0.000000
# 50%      2.000000    1.000000
# 95%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### Analyze the dataset in order to derive useful information

# %% [markdown]
# Measures of shape describe the distribution of the data within this dataset. These distributions show the spread (dispersion, variability, scatter) of the data.

# %%
n_rows, n_cols = data.shape
print(f"There exists {n_rows} domain instances with {n_cols} features in the dataset.")
# Out:
# There exists 303 domain instances with 14 features in the dataset.

# %%
features = list(data.columns)

for feature in range(len(features)):
    print("Column {0} in the dataset is {1}".format(feature+1, features[feature].title()))
# Out:
# Column 1 in the dataset is Age
# Column 2 in the dataset is Sex
# Column 3 in the dataset is Cp
# Column 4 in the dataset is Trestbps
# Column 5 in the dataset is Chol
# Column 6 in the dataset is Fbs
# Column 7 in the dataset is Restecg
# Column 8 in the dataset is Thalach
# Column 9 in the dataset is Exang
# Column 10 in the dataset is Oldpeak
# Column 11 in the dataset is Slope
# Column 12 in the dataset is Ca
# Column 13 in the dataset is Thal
# Column 14 in the dataset is Target

# %% [markdown]
# It shows that this dataset has 303 rows and 14 columns.

# %%
# We can see the names of columns here
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# Statisctial Details Describe provides us with statistical in numerical format about the specific details of each of the columns. We can deduct that in AGE column the minimum age is 29 years and maximum is 77 years mean of age is 54 years. The quantities details are given in form of 25%, 50% and 75%. The data is divided into 3 quarties of 4 eaqul parts. Those statistical measures give us an idea  of the central tendency of the data set. However, mean is effected by outliers and hence we need more information to make accurate decisions.

# %%
data.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# The dataset doesn't have missing information/ no null values.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %%
data.rename(columns ={'age':'Age','sex':'Sex','cp':'Chest_pain','trestbps':'Resting_blood_pressure','chol':'Cholesterol','fbs':'Fasting_blood_sugar',
                    'restecg':'ECG_results','thalach':'Maximum_heart_rate','exang':'Exercise_induced_angina','oldpeak':'ST_depression','ca':'Major_vessels',
                   'thal':'Thalassemia_types','target':'Heart_attack','slope':'ST_slope'}, inplace = True)

# %%
df = data.copy() # default dataset

# %% [markdown]
# Renaming the column headers for better understanding of visualizations.

# %%
df['Sex'].replace({1:'Male', 0:'Female'}, inplace=True)

df['Heart_attack'].replace({1:'Yes',0:'No'}, inplace = True)

# df['Chest_pain'].replace({1:'typical angina', 2:'atypical angina', 3:'non-anginal pain', 4:'asymptomatic'}, inplace = True)

# df['Fasting_blood_sugar'].replace({0:'lower than 120mg/ml', 1:'greater than 120mg/ml'}, inplace = True)

# df['ECG_results'].replace({0:'normal', 1:'ST-T wave abnormality', 2:'left ventricular hypertrophy'}, inplace = True)

# df['ST_slope'].replace({1:'normal', 2:'fixed defect', 3:'reversable defect'}, inplace=True)

# %% [markdown]
# We can find the types of the field which we don't need to convert to. However, we can replace some of the colummns as these will make the understanding of visualizations better instead of numeric values.

# %%
# Check of the changes
df.dtypes
# Out:
# Age                          int64
# Sex                         object
# Chest_pain                   int64
# Resting_blood_pressure       int64
# Cholesterol                  int64
# Fasting_blood_sugar          int64
# ECG_results                  int64
# Maximum_heart_rate           int64
# Exercise_induced_angina      int64
# ST_depression              float64
# ST_slope                     int64
# Major_vessels                int64
# Thalassemia_types            int64
# Heart_attack                object
# dtype: object

# %%
df['Sex'] = df['Sex'].astype('object')
df['Heart_arrack'] = df['Heart_attack'].astype('object')
# df['Chest_pain'] = df['Chest_pain'].astype('object')
# df['Fasting_blood_sugar'] = df['Fasting_blood_sugar'].astype('object')
# df['ECG_results'] = df['ECG_results'].astype('object')
# df['Exercise_induced_angina'] = df['Exercise_induced_angina'].astype('object')
# df['ST_slope '] = df['ST_slope'].astype('object')

# %% [markdown]
# ### Finding the correlation among the attributes

# %%
plt.figure(figsize=(20,10))
cm = df.corr()
sns.set(font_scale=1.1)
sns.heatmap(cm,
            cbar=True,
            annot=True,
            square=True,
            cmap='PuBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see strong positive correlation between target and cp, thalach, slope and also negative correlation between target and sex, exang, ca, thai, oldpeak.

# %%
# Plot
sns.pairplot(data=df)

# %%
df.hist(figsize=(10,20), layout=(7,2))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Chest_pain'}>],
#        [<AxesSubplot:title={'center':'Resting_blood_pressure'}>,
#         <AxesSubplot:title={'center':'Cholesterol'}>],
#        [<AxesSubplot:title={'center':'Fasting_blood_sugar'}>,
#         <AxesSubplot:title={'center':'ECG_results'}>],
#        [<AxesSubplot:title={'center':'Maximum_heart_rate'}>,
#         <AxesSubplot:title={'center':'Exercise_induced_angina'}>],
#        [<AxesSubplot:title={'center':'ST_depression'}>,
#         <AxesSubplot:title={'center':'ST_slope'}>],
#        [<AxesSubplot:title={'center':'Major_vessels'}>,
#         <AxesSubplot:title={'center':'Thalassemia_types'}>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# box and whiskers plot
df.plot(kind='box', subplots=True, layout=(7,2), figsize=(10,20))
plt.show()

# %% [markdown]
# We have got a lot of outliers.

# %%
sns.catplot(data=df, x='Sex', y='Age', hue='Heart_attack', palette='magma', legend=True) # target presents having or not having heart diseases

# %% [markdown]
# The plot shows that the majority of the males have a heart diseas.

# %% [markdown]
# Generally males having high cholesterol had higher cases of heart attacks than females at the same Cholesterol.

# %% [markdown]
# The cholesterol level of the males having a heart disease is higher than those without.

# %%
df['Sex'].value_counts()
# Out:
# Male      207
# Female     96
# Name: Sex, dtype: int64

# %% [markdown]
# 207 males and 96 females

# %%
df['Heart_attack'].value_counts()
# Out:
# Yes    165
# No     138
# Name: Heart_attack, dtype: int64

# %% [markdown]
# 165 cases of heart diseases

# %%
df['Thalassemia_types'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: Thalassemia_types, dtype: int64

# %% [markdown]
# results of thallium stress test measuring blood flow to the heart

# %%
sns.countplot(x='Sex', data=df, hue='Heart_attack', palette='PuBu')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Here 1 means male and 0 female. We observe that the males have more heart diseases than the females compared with the given dataset.

# %%
 sns.countplot(x='Heart_attack', palette=sns.color_palette("GnBu", 3), data=df)  # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Heart_attack', ylabel='count'>

# %% [markdown]
# We observer that the count for not having heart disease and having heart disease are almost balanced - the amount not having disease is 140 and those having are 160.

# %%
sort_by_heart_attack = df.groupby(['Sex','Age'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_heart_attack.head(20).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row0_col1,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row16_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row0_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row1_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row2_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row15_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row1_col1{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row2_col1{
#             background-color:  #3080bd;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row3_col1{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row3_col2{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row4_col1,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row5_col2{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row4_col2{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row5_col1{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row6_col1{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row6_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row7_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row7_col1{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row8_col1{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row8_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row9_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row10_col2{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row9_col1{
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row10_col1{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row11_col1{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row11_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row12_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row13_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row14_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row15_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row16_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row17_col2{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row12_col1{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row13_col1{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row14_col1{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row17_col1,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row18_col2,#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row19_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row18_col1{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row19_col1{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }</style><table id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >59</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row0_col1" class="data row0 col1" >58</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row0_col2" class="data row0 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >58</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row1_col1" class="data row1 col1" >57</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row1_col2" class="data row1 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >60</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row2_col0" class="data row2 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row2_col1" class="data row2 col1" >59</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row2_col2" class="data row2 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >53</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row3_col0" class="data row3 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row3_col1" class="data row3 col1" >52</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row4" class="row_heading level0 row4" >55</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row4_col0" class="data row4 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row4_col1" class="data row4 col1" >54</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row4_col2" class="data row4 col2" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row5" class="row_heading level0 row5" >45</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row5_col1" class="data row5 col1" >44</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row5_col2" class="data row5 col2" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row6" class="row_heading level0 row6" >52</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row6_col1" class="data row6 col1" >51</td>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row6_col2" class="data row6 col2" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0level0_row7" class="row_heading level0 row7" >57</th>
#                         <td id="T_811d5450_95fe_11eb_80d1_e45e37ab1cf0row7_col0" class="data row7 col0" >Male</td>
#                         <td id="T

# %% [markdown]
# This shows the total number of heart attacks that have occured for a particular age in case of males and females. In the top 20 count of heart attack, males have witnessed more heart attacks for their ages.

# %%
sns.countplot(x='Major_vessels', hue='Heart_attack', data=df, palette='PuBu') # target presents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Major_vessels', ylabel='count'>

# %% [markdown]
# ###### ca: number of major vessels (0-3) coloured by flourosopy

# %%
df['Major_vessels'].value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: Major_vessels, dtype: int64

# %% [markdown]
# ca number of major vessels (0-3) coloured by flourosopy ca has a negative corelation with the target i.e. when ca will increase we witness a drop in heart disease and vice versa.

# %%
sns.countplot(x='Thalassemia_types', data=df, hue='Heart_attack', palette=sns.color_palette("GnBu",2))  # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Thalassemia_types', ylabel='count'>

# %% [markdown]
# thal 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
sns.countplot(x='Thalassemia_types', data=df, hue='Sex', palette=sns.color_palette("PuBu", 3))
# Out:
# <AxesSubplot:xlabel='Thalassemia_types', ylabel='count'>

# %%
df['Chest_pain'].value_counts() # chest pain type
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: Chest_pain, dtype: int64

# %%
sns.countplot(x='Chest_pain', hue='Heart_attack', data=df, palette='PuBu')  # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Chest_pain', ylabel='count'>

# %% [markdown]
# Shows chest pain with respet to heart disease/target

# %% [markdown]
# Let's find how many male and female have chest pain.

# %%
sort_by_chest_pain = df.groupby(['Sex','Chest_pain'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_chest_pain.head(10).style.background_gradient(cmap='PuBu')
# Out:
# <style  type="text/css" >
# #T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row0_col1,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row2_col1,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row7_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row0_col2,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row5_col1,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row7_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row1_col1,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row3_col1{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row1_col2{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row2_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row3_col2{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row4_col1,#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row6_col1{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row4_col2{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row5_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row6_col2{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }</style><table id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >Chest_pain</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >4</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row0_col2" class="data row0 col2" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row1_col2" class="data row1 col2" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row2_col2" class="data row2 col2" >39</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row3_col1" class="data row3 col1" >2</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row3_col2" class="data row3 col2" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row4_col0" class="data row4 col0" >Male</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row4_col2" class="data row4 col2" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row5" class="row_heading level0 row5" >7</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row5_col1" class="data row5 col1" >3</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row5_col2" class="data row5 col2" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row6" class="row_heading level0 row6" >1</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row6_col0" class="data row6 col0" >Female</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row6_col1" class="data row6 col1" >1</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row6_col2" class="data row6 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0level0_row7" class="row_heading level0 row7" >3</th>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row7_col0" class="data row7 col0" >Female</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row7_col1" class="data row7 col1" >3</td>
#                         <td id="T_81b340f9_95fe_11eb_b01d_e45e37ab1cf0row7_col2" class="data row7 col2" >4</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The Males having chest pain type 0 suffered the most heart attacks and type 2 the second highest. This trend is same for females.

# %%
sns.barplot(x='Sex', y='Chest_pain', hue='Heart_attack', data=df, palette=sns.color_palette("GnBu", 2))  # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Chest_pain'>

# %%
sns.countplot(x='Chest_pain', hue='Sex', data=df, palette=sns.color_palette("GnBu", 3))
# Out:
# <AxesSubplot:xlabel='Chest_pain', ylabel='count'>

# %% [markdown]
# This shows chest pain count experienced by male and female.

# %%
sns.boxplot(x='Sex', y='Cholesterol', data=df, hue='Heart_attack', palette=sns.color_palette("GnBu", 2)) # target presents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Cholesterol'>

# %%
sns.barplot(data=df, x='Sex', y='Cholesterol', hue='Heart_attack', palette='PuBu') # target presents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Cholesterol'>

# %%
sort_by_cholesterol = df.groupby(['Sex','Cholesterol'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_cholesterol.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row0_col1{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row0_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row4_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row1_col1,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row7_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row8_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row1_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row2_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row3_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row4_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row5_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row6_col2,#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row9_col1{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row2_col1{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row3_col1{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row5_col1{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row6_col1{
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row7_col1{
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }#T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row8_col1{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >Cholesterol</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >115</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row0_col1" class="data row0 col1" >212</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row0_col2" class="data row0 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >109</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row1_col1" class="data row1 col1" >204</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row1_col2" class="data row1 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >135</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row2_col0" class="data row2 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row2_col1" class="data row2 col1" >234</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row2_col2" class="data row2 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >134</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row3_col0" class="data row3 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row3_col1" class="data row3 col1" >233</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row3_col2" class="data row3 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row4" class="row_heading level0 row4" >172</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row4_col0" class="data row4 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row4_col1" class="data row4 col1" >282</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row4_col2" class="data row4 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row5" class="row_heading level0 row5" >150</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row5_col1" class="data row5 col1" >254</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row5_col2" class="data row5 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row6" class="row_heading level0 row6" >48</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row6_col0" class="data row6 col0" >Female</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row6_col1" class="data row6 col1" >269</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row6_col2" class="data row6 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row7" class="row_heading level0 row7" >144</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row7_col0" class="data row7 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row7_col1" class="data row7 col1" >246</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row7_col2" class="data row7 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row8" class="row_heading level0 row8" >143</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row8_col0" class="data row8 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row8_col1" class="data row8 col1" >245</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row8_col2" class="data row8 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0level0_row9" class="row_heading level0 row9" >141</th>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row9_col0" class="data row9 col0" >Male</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row9_col1" class="data row9 col1" >243</td>
#                         <td id="T_8256606c_95fe_11eb_bb20_e45e37ab1cf0row9_col2" class="data row9 col2" >3</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# We observe the outliers with the help of boxplot, outliers are values that are very small or large inthe given data set.

# %%
sns.barplot(x='Sex', y='Thalassemia_types', data=df, hue='Heart_attack', palette='PuBu')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Thalassemia_types'>

# %%
sort_by_thalassemia_types = df.groupby(['Sex','Thalassemia_types'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_thalassemia_types.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row0_col1,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row0_col2,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row4_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row1_col1,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row2_col1{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row1_col2{
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row2_col2{
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row3_col1,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row6_col1{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row3_col2{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row4_col2{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row5_col1,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row5_col2,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row6_col2,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row7_col1,#T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row7_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >Thalassemia_types</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row0_col2" class="data row0 col2" >102</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row1_col2" class="data row1 col2" >87</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row2_col2" class="data row2 col2" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row3_col0" class="data row3 col0" >Male</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row3_col2" class="data row3 col2" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row4" class="row_heading level0 row4" >3</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row4_col2" class="data row4 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row5" class="row_heading level0 row5" >0</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row5_col0" class="data row5 col0" >Female</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row5_col2" class="data row5 col2" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row6" class="row_heading level0 row6" >1</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row6_col0" class="data row6 col0" >Female</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row6_col1" class="data row6 col1" >1</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row6_col2" class="data row6 col2" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0level0_row7" class="row_heading level0 row7" >4</th>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row7_col0" class="data row7 col0" >Male</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_828cbd38_95fe_11eb_8653_e45e37ab1cf0row7_col2" class="data row7 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The higher the Thalassemia type, the higher were the cases of heart attack.

# %% [markdown]
# Here I have experimented with thal and observed with the number of major vessels 'ca'

# %%
sns.barplot(x='Heart_attack', y='Major_vessels', hue='Sex', data=df, palette=sns.color_palette("GnBu", 3))
# Out:
# <AxesSubplot:xlabel='Heart_attack', ylabel='Major_vessels'>

# %%
sns.barplot(x='Sex', y='ST_depression', data=df, hue='Heart_attack', palette='PuBu')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='ST_depression'>

# %%
sort_by_st_depression = df.groupby(['Sex','ST_depression'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_st_depression.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row0_col1,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row1_col1,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row8_col2,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row0_col2,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row8_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row1_col2{
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row2_col1{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row2_col2{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row3_col1{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row3_col2{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row4_col1{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row4_col2{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row5_col1{
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row5_col2,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row6_col2,#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row7_col2{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row6_col1{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row7_col1{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row9_col1{
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }</style><table id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >ST_depression</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >27</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row0_col2" class="data row0 col2" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row1_col0" class="data row1 col0" >Female</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row1_col2" class="data row1 col2" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >37</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row2_col0" class="data row2 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row2_col1" class="data row2 col1" >1.200000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row2_col2" class="data row2 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >34</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row3_col0" class="data row3 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row3_col1" class="data row3 col1" >0.800000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row3_col2" class="data row3 col2" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row4" class="row_heading level0 row4" >36</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row4_col0" class="data row4 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row4_col1" class="data row4 col1" >1.000000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row4_col2" class="data row4 col2" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row5" class="row_heading level0 row5" >41</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row5_col1" class="data row5 col1" >1.800000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row5_col2" class="data row5 col2" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row6" class="row_heading level0 row6" >38</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row6_col1" class="data row6 col1" >1.400000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row6_col2" class="data row6 col2" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row7" class="row_heading level0 row7" >33</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row7_col0" class="data row7 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row7_col1" class="data row7 col1" >0.600000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row7_col2" class="data row7 col2" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row8" class="row_heading level0 row8" >43</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row8_col0" class="data row8 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row8_col1" class="data row8 col1" >2.000000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row8_col2" class="data row8 col2" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0level0_row9" class="row_heading level0 row9" >40</th>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row9_col0" class="data row9 col0" >Male</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row9_col1" class="data row9 col1" >1.600000</td>
#                         <td id="T_82f328ec_95fe_11eb_b75b_e45e37ab1cf0row9_col2" class="data row9 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The lower the depression, the higher the cases were for heart attack.

# %% [markdown]
# ###### oldpeak = ST depression induced by exercise relative to rest, measures of abnormality in electrocardiograms

# %%
df['Fasting_blood_sugar'].value_counts()
# Out:
# 0    258
# 1     45
# Name: Fasting_blood_sugar, dtype: int64

# %% [markdown]
# ###### fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false) and chest pain relation

# %%
sns.barplot(x='Fasting_blood_sugar', y='Cholesterol', data=df, hue='Heart_attack', palette=sns.color_palette("GnBu", 2))  # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Fasting_blood_sugar', ylabel='Cholesterol'>

# %%
sns.barplot(x='Heart_attack', y='Fasting_blood_sugar', data=df, hue='Sex', palette=sns.color_palette("GnBu", 3))
# Out:
# <AxesSubplot:xlabel='Heart_attack', ylabel='Fasting_blood_sugar'>

# %%
sort_by_fasting_blood_sugar = df.groupby(['Sex','Fasting_blood_sugar'])['Heart_attack'].count().reset_index().sort_values(by='Heart_attack',ascending=False)
sort_by_fasting_blood_sugar.head(10).style.background_gradient(cmap='GnBu')
# Out:
# <style  type="text/css" >
# #T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row0_col1,#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row1_col1,#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row3_col2{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row0_col2,#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row2_col1,#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row1_col2{
#             background-color:  #8fd4bd;
#             color:  #000000;
#         }#T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row2_col2{
#             background-color:  #dff3da;
#             color:  #000000;
#         }</style><table id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sex</th>        <th class="col_heading level0 col1" >Fasting_blood_sugar</th>        <th class="col_heading level0 col2" >Heart_attack</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row0_col2" class="data row0 col2" >174</td>
#             </tr>
#             <tr>
#                         <th id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row1_col0" class="data row1 col0" >Female</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row1_col2" class="data row1 col2" >84</td>
#             </tr>
#             <tr>
#                         <th id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row2_col0" class="data row2 col0" >Male</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row2_col2" class="data row2 col2" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0level0_row3" class="row_heading level0 row3" >1</th>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_8351b724_95fe_11eb_b9d8_e45e37ab1cf0row3_col2" class="data row3 col2" >12</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# This shows relation of Fasting blood sugar with heart attack in case of Male and Females.

# %% [markdown]
# #### Cross tables

# %%
tb_heart_disease = pd.crosstab(df['Sex'], df['Heart_attack'])
tb_heart_disease
# Out:
# Heart_attack   No  Yes
# Sex
# Female         24   72
# Male          114   93

# %%
# tb_heart_disease.plot(kind='bar', stacked=True, color=['lightblue', 'teal'], grid=True)
tb_heart_disease.plot(kind='bar', stacked=True, color=sns.color_palette("GnBu", 3), grid=True)
# Out:
# <AxesSubplot:xlabel='Sex'>

# %% [markdown]
# Explanation: females not having heart diseases are 24, having heart diseases are 72 compared to males having heart disease are 114 and not having 93;

# %%
tb_thal = pd.crosstab(index=df['Heart_attack'], columns=[df['Thalassemia_types']], margins=True)
tb_thal
# Out:
# Thalassemia_types  0   1    2    3  All
# Heart_attack
# No                 1  12   36   89  138
# Yes                1   6  130   28  165
# All                2  18  166  117  303

# %% [markdown]
# Let's plot it. As you can see the chances males closer to the 130 are more likely to have a heart disease.

# %%
tb_thal.plot(kind='bar', stacked=True, color=sns.color_palette("GnBu", 5))
plt.show()

# %%
tb_chest_pain = pd.crosstab(df['Chest_pain'], df['Heart_attack'])
tb_chest_pain
# Out:
# Heart_attack   No  Yes
# Chest_pain
# 0             104   39
# 1               9   41
# 2              18   69
# 3               7   16

# %%
tb_chest_pain.plot(kind='bar', stacked=True, color=sns.color_palette("GnBu", 3), grid=True) # target represents having or not having heart diseases
# Out:
# <AxesSubplot:xlabel='Chest_pain'>

# %% [markdown]
# ### Bivariate Analysis

# %%
# Change defaults
sns.set_style('whitegrid')
sns.set_context('talk')
sns.set_palette('rainbow')

plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Heart_attack', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of Heart Attack on Age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Chest_pain', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of Chest pain on Age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Fasting_blood_sugar', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of Fasting blood sugar on age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'ECG_results', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of ECG on age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Exercise_induced_angina', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of Exercise Induced Angina on age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'ST_slope', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of ST Slope on age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Major_vessels', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of Major vessels being blocked with age.

# %%
plt.figure(figsize=(20, 10)) # change the size of the plot
sns.countplot(x = 'Age',hue = 'Thalassemia_types', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# The dependence of result of Thalassemia on age.

# %%
sns.set(font_scale=0.9) # change the font size for the next plots

sns.relplot(x ='Age', y ='Chest_pain', col = 'Sex', data = df, color="teal", height = 5)

# %% [markdown]
# Relationship between Chest Pain, Age and Sex.

# %%
sns.relplot(x ='Age', y ='Resting_blood_pressure', col = 'Sex', data = df, color = 'grey')

# %%
sns.relplot(x ='Age', y ='Cholesterol', col = 'Sex', data = df, color = 'turquoise')

# %% [markdown]
# Relationship between Cholesterol, Age and Sex.

# %%
sns.relplot(x ='Age', y ='Fasting_blood_sugar', col = 'Sex', data = df, color = 'teal')

# %% [markdown]
# Relationship between Fasting Blood Sugar, Age and Sex.

# %%
sns.relplot(x ='Age', y ='ECG_results', col = 'Sex', data = df, color = 'grey')

# %% [markdown]
# Relationship between ECG Results, Age and Sex.

# %%
sns.relplot(x ='Age', y ='Maximum_heart_rate', col = 'Sex', data = df, color = 'turquoise')

# %% [markdown]
# Relationship between Maximum Heart Rate, Age and Sex.

# %%
sns.jointplot(x =df['Age'], y =df['Exercise_induced_angina'], data = df, color = 'teal')

# %% [markdown]
# Relationship between Exercise Induced Angina and Age. The Age peaks at about 60 and Exercise Induced Angina problem is more at value 0.

# %%
sns.relplot(x ='Age', y ='ST_depression', col = 'Sex', data = df, color = 'teal')

# %% [markdown]
# Relationship between ST_depression, Age and Sex.

# %%
sns.relplot(x ='Age', y ='Major_vessels', col = 'Sex', data = df, color = 'grey')

# %% [markdown]
# Relationship between Major_vessels, Age and Sex.

# %%
sns.relplot(x ='Age', y ='Thalassemia_types', col = 'Sex', data = df, color = 'turquoise')

# %% [markdown]
# Relationship between Thalassemia type, Age and Sex.

# %% [markdown]
# #### Summary
#
# The overall graphical analysis shows that females tend to suffer less from heart disease and that men have a higher chances of getting struck by a heart disease. All men indepenitelly the age group are suffering from heart disease which isn't the case with women.
#
# Age is not such a huge critera for suffering from heart disease and parameters had very little relation amongst themselves.
#
# The research taken showed various results where the patterns showed that the heart disease conditions could have been diagonsed a bit earlier.

# %% [markdown]
# ### Apply Exploratory Data Analysis (EDA)

# %%
# Libraries for model selection
from sklearn.ensemble import RandomForestClassifier #for the model
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz #plot tree
from sklearn.metrics import roc_curve, auc #for model evaluation
from sklearn.metrics import classification_report #for model evaluation
from sklearn.metrics import confusion_matrix #for model evaluation
from sklearn.model_selection import train_test_split #for data splitting

import eli5 #for purmutation importance
from eli5.sklearn import PermutationImportance
import shap #for SHAP (SHapley Additive exPlanations) values
from pdpbox import pdp, info_plots #for partial plots
np.random.seed(123) #ensure reproducibility

pd.options.mode.chained_assignment = None  #hide any pandas warnings

# %% [markdown]
# ### Classification Model

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('Heart_attack', 1), data['Heart_attack'], test_size= .2, random_state=10) # split the data

# %%
# Model
model = RandomForestClassifier(max_depth=5)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %% [markdown]
# We can plot the consequent decision tree, to see what it's doing

# %%
estimator = model.estimators_[1]
feature_names = [i for i in X_train.columns]

y_train_str = y_train.astype('str')
y_train_str[y_train_str == '0'] = 'no disease'
y_train_str[y_train_str == '1'] = 'disease'
y_train_str = y_train_str.values

# %% [markdown]
# **Visualize a Decision Tree from a Random Forest in Python**

# %%
# code from https://towardsdatascience.com/how-to-visualize-a-decision-tree-from-a-random-forest-in-python-using-scikit-learn-38ad2d75f21c

# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = feature_names,
                class_names = y_train_str,
                rounded = True, proportion = True, 
                label='root',
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'], shell=True)

# Display in jupyter notebook
# from IPython.display import Image
# Image(filename = 'tree.png')
# Out:
# 1
